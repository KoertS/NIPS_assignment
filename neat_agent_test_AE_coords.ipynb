# %%
import numpy as np
import PIL
import neat
import cv2

import mxnet as mx
import numpy as np
import torch
from mxnet import gluon
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-1-5e304eea61bf> in <module>
#       4 import cv2
#       5
# ----> 6 import mxnet as mx
#       7 import numpy as np
#       8 import torch
#
# ~\AppData\Roaming\Python\Python38\site-packages\mxnet\__init__.py in <module>
#      22 from __future__ import absolute_import
#      23
# ---> 24 from .context import Context, current_context, cpu, gpu, cpu_pinned
#      25 from . import engine
#      26 from .base import MXNetError
#
# ~\AppData\Roaming\Python\Python38\site-packages\mxnet\context.py in <module>
#      22 import warnings
#      23 import ctypes
# ---> 24 from .base import classproperty, with_metaclass, _MXClassPropertyMetaClass
#      25 from .base import _LIB
#      26 from .base import check_call
#
# ~\AppData\Roaming\Python\Python38\site-packages\mxnet\base.py in <module>
#     212 __version__ = libinfo.__version__
#     213 # library instance of mxnet
# --> 214 _LIB = _load_lib()
#     215
#     216 # type definitions
#
# ~\AppData\Roaming\Python\Python38\site-packages\mxnet\base.py in _load_lib()
#     202 def _load_lib():
#     203     """Load library by searching possible path."""
# --> 204     lib_path = libinfo.find_lib_path()
#     205     lib = ctypes.CDLL(lib_path[0], ctypes.RTLD_LOCAL)
#     206     # DMatrix functions
#
# ~\AppData\Roaming\Python\Python38\site-packages\mxnet\libinfo.py in find_lib_path(prefix)
#      71     lib_path = [p for p in dll_path if os.path.exists(p) and os.path.isfile(p)]
#      72     if len(lib_path) == 0:
# ---> 73         raise RuntimeError('Cannot find the MXNet library.\n' +
#      74                            'List of candidates:\n' + str('\n'.join(dll_path)))
#      75     if os.name == 'nt':
#
# RuntimeError: Cannot find the MXNet library.
# List of candidates:
# C:\Users\Koert\AppData\Roaming\Python\Python38\site-packages\mxnet\libmxnet.dll
# C:\Users\Koert\AppData\Roaming\Python\Python38\site-packages\mxnet\../../lib/libmxnet.dll
# C:\Users\Koert\AppData\Roaming\Python\Python38\site-packages\mxnet\../../build/libmxnet.dll
# C:\Users\Koert\AppData\Roaming\Python\Python38\site-packages\mxnet\../../build\libmxnet.dll
# C:\Users\Koert\AppData\Roaming\Python\Python38\site-packages\mxnet\../../build\Release\libmxnet.dll
# C:\Users\Koert\AppData\Roaming\Python\Python38\site-packages\mxnet\../../windows\Release\libmxnet.dll

# %% [markdown]
# ### **SOW-MKI49-2020-SEM1-V: NeurIPS**
# #### Project: Neurosmash
#
# This is the info document on the Neurosmash environment that you will be using for your Final Assignment. It contains background info and skeleton code to get you started.

# %% [markdown]
# ### Project
#
# During the 2nd period, you will be working exclusively on this final group project in the practicals. You are expected to form groups of 4-5 people. The goal is to take what has been discussed in class and what you have already worked on in the earlier practicals, and apply them on a RL problem in a novel environment. This  project will constitute 25% of your final grade.
#
# Your project grade will be based on the following components:
# - Online demonstration
# - Source code
# - Written report (a 4-page report in NeurIPS workshop paper format: https://www.overleaf.com/latex/templates/neurips-2020/mnshsmqkjsqz)
#
# These components will be evaluated based on performance, creativity, elegance, rigor and plausibility.
#
# While you can use the material from earlier practicals (e.g., REINFORCE, DQN, etc.) as a boilerplate, you are also free to take any other approach be it imitation learning or world models for your project.
#
# As a deep learning library, use of mxnet is preferred. Still, you are free to use whatever you want.
#
# In addition to the practical sessions, we will provide additional support in the coming weeks. You can email any of us to set up an appointment for discussing your project.

# %% [markdown]
# ### Environment
#
# Briefly, there are two agents: Red and Blue. Red is controlled by you. Blue is controlled by the environment "AI".* Both agents always run forward with a speed of 3.5 m/s*. If one of them gets within the reach of the other (a frontal sphere with 0.5 m radius), it gets pushed away automatically with a speed of 3.5 m/s. The only thing that the agents can do is to turn left or right with an angular speed of 180 degrees/s. This means that there are three possible discrete actions that your agent can take every step: Turn nowhere, turn left and turn right. For convenience, there is also a fourth built-in action which turns left or right with uniform probability. An episode begins when you reset the environment and ends when one of the agents fall off the platform. At the end of the episode, the winning agent gets a reward of 10 while the other gets nothing. Therefore, your goal is to train an agent who can maximize its reward by pushing the other agent off the platform or making it fall off the platform by itself.
#
# * Note that all times are simulation time. That is, 0.02 s per step when timescale is set to one.
#
# * Basically, Blue is artificial but not really intelligent. What it does is that every 0.5 s, it updates its destination to the current position of Red plus some random variation (a surrounding circle with a radius of 1.75 m) and smoothly turns to that position.
#
# Note to macOS users: You should first make the environment executable* in the terminal and run it from the context menu (i.e., not by double clicking)
#
# * chmod -R +x [Path of Mac.app (which is in the .zip file)]/Contents/MacOS

# %% [markdown]
# ### Skeleton code
#
# - You should first add the Neurosmash file to your working directory or Python path.
# - Next you should start the Neurosmash app
# - Make sure to set the right values in the Ip, Port, Size and Timescale fields (see below). These must correspond to the values you specify in the python script
# - Start the server by pressing the play button
# - The fastest simulations can be obtained by turning off rendering (x button)

# %%
import Neurosmash

# These are the default environment arguments. They must be the same as the values that are set in the environment GUI.
ip         = "127.0.0.1" # Ip address that the TCP/IP interface listens to (127.0.0.1 by default)
port       = 13000       # Port number that the TCP/IP interface listens to (13000 by default)

# This is the size of the texture that the environment is rendered.
# This is set to 784 by default, which will result in a crisp image but slow speed.
# You can change the size to a value that works well for your environment but should not go too low.
size       = 240

# This is the simulation speed of the environment. This is set to 1 by default.
# Setting it to n will make the simulation n times faster.
# In other words, less (if n < 1) or more (if n > 1) simulation time will pass per step.
# You might want to increase this value to around 10 if you cannot train your models fast enough
# so that they can sample more states in a shorter number of steps at the expense of precision.
timescale  = 20

# This is an example agent.
# It has a step function, which gets reward/state as arguments and returns an action.
# Right now, it always outputs a random action (3) regardless of reward/state.
# The real agent should output one of the following three actions:
# none (0), left (1) and right (2)
agent = Neurosmash.Agent() 

# This is the main environment.
# It has a reset function, which is used to reset the environment before episodes.
# It also has a step function, which is used to which steps one time point
# It gets an action (as defined above) as input and outputs the following:
# end (true if the episode has ended, false otherwise)
# reward (10 if won, 0 otherwise)
# state (flattened size x size x 3 vector of pixel values)
# The state can be converted into an image as follows:
# image = np.array(state, "uint8").reshape(size, size, 3)
# You can also use to Neurosmash.Environment.state2image(state) function which returns
# the state as a PIL image
environment = Neurosmash.Environment(ip, port, size, timescale)

# %%
class autoencoder(gluon.Block):
    def __init__(self):
        super(autoencoder, self).__init__()
        with self.name_scope():
            self.encoder = gluon.nn.Sequential('encoder_')
            with self.encoder.name_scope():
                self.encoder.add(gluon.nn.Dense(2, in_units = 4))

            self.decoder = gluon.nn.Sequential('decoder_')
            with self.decoder.name_scope():
                self.decoder.add(gluon.nn.Dense(4, in_units = 2))

    def encode(self, x):
      return self.encoder(x)

    def decode(self, x):
      return self.decoder(x)

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x
model = autoencoder()
model.load_parameters('./simple_autoencoder.params', ctx=ctx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-cfa521110f2c> in <module>
# ----> 1 class autoencoder(gluon.Block):
#       2     def __init__(self):
#       3         super(autoencoder, self).__init__()
#       4         with self.name_scope():
#       5             self.encoder = gluon.nn.Sequential('encoder_')
#
# NameError: name 'gluon' is not defined

# %%
action_dict = {0: 'n', 1: 'l', 2: 'r'}
def get_color_coords(image):
    boundaries = [
    ([17, 15, 130], [80, 100, 200]), #Blue
    ([86, 31, 4], [220, 88, 50]), #Red
    ]
    coords = []
    for (lower, upper) in boundaries:
        # create NumPy arrays from the boundaries
        lower = np.array(lower, dtype = "uint8")
        upper = np.array(upper, dtype = "uint8")
        # find the colors within the specified boundaries and apply
        # the mask
        mask = cv2.inRange(image, lower, upper)
        output = cv2.bitwise_and(image, image, mask = mask)
        coords.append(np.mean(np.array(list(set(zip(np.nonzero(output)[0],np.nonzero(output)[1])))), axis = 0))
    for idx in range(len(coords)):
        if np.isnan(coords[idx]).all():
            coords[idx] = np.array([0,0])
    return np.array(coords)-size/2

# %%
sample_coords = []

# %%
def fitness(genomes, config):
    for g_id, g in genomes:
        g.fitness = 0
        net = neat.nn.FeedForwardNetwork.create(g, config)
        action_ls = []
        
        end, reward, state = environment.reset()
        while (end == 0):
            image = np.array(state, "uint8").reshape(size, size, 3)
            coords = get_color_coords(image).flatten()
            sample_coords.append(coords)
            inputs = coords.extend(autoencoder.encode(mx.nd.array(coords)))
            output = net.activate(inputs)
            action = np.argmax(output)
            action_ls.append(action_dict[action])
            end, reward, state = environment.step(action)
            g.fitness -=0.01
        g.fitness+=reward
       # print(action_ls)

# %%
def run(config_file):
    # Load configuration.
    config = neat.Config(neat.DefaultGenome, neat.DefaultReproduction,
                         neat.DefaultSpeciesSet, neat.DefaultStagnation,
                         config_file)

    # Create the population, which is the top-level object for a NEAT run.
    p = neat.Population(config)

    # Add a stdout reporter to show progress in the terminal.
    p.add_reporter(neat.StdOutReporter(True))
    stats = neat.StatisticsReporter()
    p.add_reporter(stats)

    # Run for up to 25 generations.eval_genomes
    winner = p.run(fitness, 25)

#     # Display the winning genome.
#     print('\nBest genome:\n{!s}'.format(winner))

#     # Show output of the most fit genome against training data.
#     print('\nOutput:')
#     winner_net = neat.nn.FeedForwardNetwork.create(winner, config)
#     for xi, xo in zip(xor_inputs, xor_outputs):
#         output = winner_net.activate(xi)
#         print("input {!r}, expected output {!r}, got {!r}".format(xi, xo, output))

#     node_names = {-1:'A', -2: 'B', 0:'A XOR B'}
#     visualize.draw_net(config, winner, True, node_names=node_names)
#     visualize.plot_stats(stats, ylog=False, view=True)
#     visualize.plot_species(stats, view=True)

#     p = neat.Checkpointer.restore_checkpoint('neat-checkpoint-4')
#     p.run(eval_genomes, 10)

# %%
config_path =  'config-feedforward'
run(config_path)
# Out:
#  ****** Running generation 0 ******
#
# ['n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'r', 'r', 'r', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# ['n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l']
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: 3.12000 stdev: 4.71004
# Best fitness: 9.78000 - size: (3, 12) - species 1 - id 2
# Average adjusted fitness: 0.340
# Mean genetic distance 1.106, standard deviation 0.209
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    0     3      9.8    0.340     0
# Total extinctions: 0
# Generation time: 6.574 sec
#
#  ****** Running generation 1 ******
#
# ['n', 'n', 'n', 'n', 'n', 'n', 'n', 'l', 'l', 'l', 'l', 'l', 'l', 'n', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'r', 'r', 'r', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'l', 'l', 'l', 'l', 'l', 'n', 'n', 'n', 'l', 'n', 'n', 'n', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l']
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: -0.35667 stdev: 0.37026
# Best fitness: -0.08000 - size: (3, 12) - species 1 - id 4
# Average adjusted fitness: 0.523
# Mean genetic distance 0.900, standard deviation 0.247
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    1     3     -0.1    0.523     1
# Total extinctions: 0
# Generation time: 11.039 sec (8.807 average)
#
#  ****** Running generation 2 ******
#
# ['l', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# ['n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: -0.12000 stdev: 0.02944
# Best fitness: -0.09000 - size: (3, 12) - species 1 - id 4
# Average adjusted fitness: 0.040
# Mean genetic distance 0.588, standard deviation 0.299
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    2     3     -0.1    0.040     2
# Total extinctions: 0
# Generation time: 3.997 sec (7.203 average)
#
#  ****** Running generation 3 ******
#
# ['l', 'l', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# ['n', 'n', 'n', 'n', 'n', 'n', 'n', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: -0.17333 stdev: 0.11898
# Best fitness: -0.07000 - size: (3, 12) - species 1 - id 4
# Average adjusted fitness: 0.167
# Mean genetic distance 0.538, standard deviation 0.269
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    3     3     -0.1    0.167     3
# Total extinctions: 0
# Generation time: 5.550 sec (6.790 average)
#
#  ****** Running generation 4 ******
#
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: -0.09333 stdev: 0.01247
# Best fitness: -0.08000 - size: (3, 12) - species 1 - id 4
# Average adjusted fitness: 0.017
# Mean genetic distance 0.470, standard deviation 0.247
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    4     3     -0.1    0.017     4
# Total extinctions: 0
# Generation time: 3.163 sec (6.065 average)
#
#  ****** Running generation 5 ******
#
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: -0.09000 stdev: 0.01414
# Best fitness: -0.08000 - size: (3, 12) - species 1 - id 4
# Average adjusted fitness: 0.020
# Mean genetic distance 0.334, standard deviation 0.183
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    5     3     -0.1    0.020     5
# Total extinctions: 0
# Generation time: 2.921 sec (5.541 average)
#
#  ****** Running generation 6 ******
#
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: -0.08000 stdev: 0.00000
# Best fitness: -0.08000 - size: (3, 12) - species 1 - id 4
# Average adjusted fitness: 0.000
# Mean genetic distance 0.583, standard deviation 0.356
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    6     3     -0.1    0.000     6
# Total extinctions: 0
# Generation time: 2.784 sec (5.147 average)
#
#  ****** Running generation 7 ******
#
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'l', 'l', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'n', 'n']
# Population's average fitness: 3.15667 stdev: 4.57734
# Best fitness: 9.63000 - size: (4, 13) - species 1 - id 10
# Average adjusted fitness: 0.333
# Mean genetic distance 0.551, standard deviation 0.365
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    7     3      9.6    0.333     7
# Total extinctions: 0
# Generation time: 5.660 sec (5.211 average)
#
#  ****** Running generation 8 ******
#
# ['l', 'l', 'l', 'l', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'n', 'n', 'r', 'r', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'n', 'n', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r']
# Population's average fitness: 3.03333 stdev: 4.44541
# Best fitness: 9.32000 - size: (4, 13) - species 1 - id 10
# Average adjusted fitness: 0.335
# Mean genetic distance 0.770, standard deviation 0.385
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    8     3      9.3    0.335     8
# Total extinctions: 0
# Generation time: 9.151 sec (5.649 average)
#
#  ****** Running generation 9 ******
#
# ['l', 'l', 'l', 'l', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'r', 'r', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'l', 'l', 'l', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# Population's average fitness: 6.44667 stdev: 4.61523
# Best fitness: 9.76000 - size: (4, 13) - species 1 - id 10
# Average adjusted fitness: 0.663
# Mean genetic distance 0.792, standard deviation 0.264
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1    9     3      9.8    0.663     9
# Total extinctions: 0
# Generation time: 6.753 sec (5.759 average)
#
#  ****** Running generation 10 ******
#
# ['l', 'l', 'l', 'l', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'l', 'l', 'l', 'l', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'l', 'r', 'r', 'r', 'r', 'r', 'l', 'l', 'l', 'r', 'r', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: 2.79000 stdev: 4.82316
# Best fitness: 9.61000 - size: (4, 13) - species 1 - id 10
# Average adjusted fitness: 0.340
# Mean genetic distance 0.447, standard deviation 0.275
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   10     3      9.6    0.340    10
# Total extinctions: 0
# Generation time: 16.463 sec (6.748 average)
#
#  ****** Running generation 11 ******
# ['l', 'l', 'l', 'l', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r']
# ['n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: 3.18000 stdev: 4.70934
# Best fitness: 9.84000 - size: (4, 13) - species 1 - id 10
# Average adjusted fitness: 0.334
# Mean genetic distance 0.406, standard deviation 0.233
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   11     3      9.8    0.334     0
# Total extinctions: 0
# Generation time: 4.841 sec (6.129 average)
#
#  ****** Running generation 12 ******
#
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'r', 'r', 'r']
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'r']
# ['l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l']
# Population's average fitness: -0.14333 stdev: 0.05437
# Best fitness: -0.10000 - size: (4, 13) - species 1 - id 12
# Average adjusted fitness: 0.077
# Mean genetic distance 0.412, standard deviation 0.239
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   12     3     -0.1    0.077     1
# Total extinctions: 0
# Generation time: 4.679 sec (6.197 average)
#
#  ****** Running generation 13 ******
#
# ['l', 'l', 'l', 'l', 'l', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'l', 'l', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'r', 'r']
# ['l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'l', 'r', 'r', 'r', 'l', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'l', 'l', 'l', 'l', 'r', 'r', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l']
# Population's average fitness: 8.31667 stdev: 1.57320
# Best fitness: 9.59000 - size: (4, 13) - species 1 - id 10
# Average adjusted fitness: 0.635
# Mean genetic distance 0.421, standard deviation 0.248
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   13     3      9.6    0.635     2
# Total extinctions: 0
# Generation time: 49.453 sec (10.587 average)
#
#  ****** Running generation 14 ******
#
# ['l', 'l', 'l', 'l', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'r', 'r', 'r']
# ['l', 'l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: 3.12667 stdev: 4.69093
# Best fitness: 9.76000 - size: (4, 13) - species 1 - id 10
# Average adjusted fitness: 0.339
# Mean genetic distance 0.407, standard deviation 0.234
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   14     3      9.8    0.339     3
# Total extinctions: 0
# Generation time: 6.328 sec (10.903 average)
#
#  ****** Running generation 15 ******
#
# ['l', 'l', 'l', 'l', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'r', 'r', 'r']
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'n', 'n', 'n', 'n', 'n', 'n', 'r', 'n', 'n', 'n', 'n']
# Population's average fitness: 6.47000 stdev: 4.66005
# Best fitness: 9.82000 - size: (4, 13) - species 1 - id 10
# Average adjusted fitness: 0.663
# Mean genetic distance 0.374, standard deviation 0.203
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   15     3      9.8    0.663     4
# Total extinctions: 0
# Generation time: 6.282 sec (11.239 average)
#
#  ****** Running generation 16 ******
#
# ['l', 'l', 'l', 'l', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'r', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'n', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'n', 'r']
# ['l', 'l', 'l', 'l', 'l', 'n', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: 6.40333 stdev: 4.58746
# Best fitness: 9.85000 - size: (4, 13) - species 1 - id 12
# Average adjusted fitness: 0.653
# Mean genetic distance 0.309, standard deviation 0.155
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   16     3      9.8    0.653     0
# Total extinctions: 0
# Generation time: 8.069 sec (11.768 average)
#
#  ****** Running generation 17 ******
#
# ['l', 'l', 'l', 'l', 'l', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'r', 'r', 'r']
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: 2.97000 stdev: 4.33458
# Best fitness: 9.10000 - size: (4, 13) - species 1 - id 12
# Average adjusted fitness: 0.334
# Mean genetic distance 0.592, standard deviation 0.229
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   17     3      9.1    0.334     1
# Total extinctions: 0
# Generation time: 11.412 sec (12.343 average)
#
#  ****** Running generation 18 ******
#
# ['l', 'l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'n', 'n', 'n', 'n', 'n', 'n']
# ['n', 'n', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'r', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: 2.69667 stdev: 4.00483
# Best fitness: 8.36000 - size: (4, 13) - species 1 - id 12
# Average adjusted fitness: 0.338
# Mean genetic distance 0.762, standard deviation 0.549
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   18     3      8.4    0.338     2
# Total extinctions: 0
# Generation time: 19.204 sec (13.348 average)
#
#  ****** Running generation 19 ******
#
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'r', 'r', 'r']
# ['l', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# Population's average fitness: -0.12333 stdev: 0.01247
# Best fitness: -0.11000 - size: (4, 13) - species 1 - id 12
# Average adjusted fitness: 0.017
# Mean genetic distance 0.719, standard deviation 0.571
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   19     3     -0.1    0.017     3
# Total extinctions: 0
# Generation time: 4.007 sec (13.074 average)
#
#  ****** Running generation 20 ******
#
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n']
# ['l', 'l', 'n', 'n', 'n', 'n', 'r', 'r']
# Population's average fitness: 3.20667 stdev: 4.67636
# Best fitness: 9.82000 - size: (4, 13) - species 1 - id 12
# Average adjusted fitness: 0.335
# Mean genetic distance 0.594, standard deviation 0.424
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   20     3      9.8    0.335     4
# Total extinctions: 0
# Generation time: 4.076 sec (11.835 average)
#
#  ****** Running generation 21 ******
#
# ['l', 'l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'n', 'n', 'r', 'r', 'r', 'r', 'n', 'r', 'n', 'n', 'r', 'n', 'n', 'r', 'r']
# ['l', 'l', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# Population's average fitness: 3.07000 stdev: 4.58205
# Best fitness: 9.55000 - size: (4, 13) - species 1 - id 12
# Average adjusted fitness: 0.333
# Mean genetic distance 0.648, standard deviation 0.405
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   21     3      9.5    0.333     5
# Total extinctions: 0
# Generation time: 8.048 sec (12.156 average)
#
#  ****** Running generation 22 ******
#
# ['l', 'l', 'l', 'l', 'n', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'l', 'l', 'l', 'l', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'n', 'l']
# Population's average fitness: 6.41667 stdev: 4.68582
# Best fitness: 9.76000 - size: (4, 13) - species 1 - id 12
# Average adjusted fitness: 0.665
# Mean genetic distance 0.693, standard deviation 0.396
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   22     3      9.8    0.665     6
# Total extinctions: 0
# Generation time: 7.783 sec (12.466 average)
#
#  ****** Running generation 23 ******
#
# ['l', 'l', 'l', 'l', 'l', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'l', 'l', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# Population's average fitness: 9.45667 stdev: 0.26637
# Best fitness: 9.74000 - size: (4, 13) - species 1 - id 12
# Average adjusted fitness: 0.357
# Mean genetic distance 0.343, standard deviation 0.263
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   23     3      9.7    0.357     7
# Total extinctions: 0
# Generation time: 16.651 sec (9.186 average)
#
#  ****** Running generation 24 ******
#
# ['l', 'l', 'l', 'l', 'l', 'n', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'l', 'l', 'l', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r']
# ['l', 'l', 'l', 'l', 'l', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'r', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'l', 'n', 'n', 'r', 'r', 'r', 'r', 'r', 'r']
# Population's average fitness: 9.63000 stdev: 0.00816
# Best fitness: 9.64000 - size: (4, 13) - species 1 - id 12
# Average adjusted fitness: 0.010
# Mean genetic distance 0.347, standard deviation 0.261
# Population of 3 members in 1 species:
#    ID   age  size  fitness  adj fit  stag
#   ====  ===  ====  =======  =======  ====
#      1   24     3      9.6    0.010     8
# Total extinctions: 0
# Generation time: 10.937 sec (9.647 average)

# %%
# save coordinate data
np.savetxt("sample_coords.csv", sample_coords, delimiter=",")
